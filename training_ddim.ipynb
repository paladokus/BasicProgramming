# %% [markdown]
# <a href="https://colab.research.google.com/github/paladokus/BasicProgramming/blob/main/training_ddim.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Connect to gdrive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# *Clone* the code if hasn't been done

# %%
# %cd /content/drive/MyDrive/Colab\ Notebooks/
# !git clone https://github.com/ghif/diffusion-keras3.git

# %% [markdown]
# Go to the target repository

# %%
# %cd /content/drive/MyDrive/Colab\ Notebooks/diffusion-keras3
# !pwd
# Out:
# [Errno 2] No such file or directory: '/content/drive/MyDrive/Colab Notebooks/diffusion-keras3'
# /content
# /content

# %% [markdown]
# Pull the latest changes

# %%
# !git pull origin main
# Out:
# fatal: not a git repository (or any of the parent directories): .git

# %% [markdown]
# Execute the diffusion model training

# %%
# !python -i training.py
# Out:
# 2025-05-22 14:35:24.141305: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-05-22 14:35:24.159136: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1747924524.181380   54575 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1747924524.188220   54575 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...
